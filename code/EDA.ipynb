# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2021-10-29 14:20:42.772413

# %%
property_2016 = pd.read_csv('../data/properties_2016.csv')
property_2016.head()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (22,32,34,49,55) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# 0                NaN         NaN  ...              NaN            NaN
# 1                NaN         NaN  ...              NaN            NaN
# 2                NaN         NaN  ...              NaN            NaN
# 3                NaN         NaN  ...              1.0            NaN
# 4                NaN         NaN  ...              NaN            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                9.0          2015.0
# 1                         NaN            27516.0          2015.0
# 2                    650756.0          1413387.0          2015.0
# 3                    571346.0          1156834.0          2015.0
# 4                    193796.0           433491.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0        NaN                 NaN                 NaN
# 1                27516.0        NaN                 NaN                 NaN
# 2               762631.0   20800.37                 NaN                 NaN
# 3               585488.0   14557.57                 NaN                 NaN
# 4               239695.0    5725.17                 NaN                 NaN
#
#    censustractandblock
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 58 columns]

# %%
property_2017 = pd.read_csv('../data/properties_2017.csv')
property_2017.head()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  5.0                    NaN
# 3          0.0         0.0                  3.0                    6.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# 0                NaN         NaN  ...              NaN            NaN
# 1                NaN         NaN  ...              NaN            NaN
# 2                NaN         NaN  ...              1.0            NaN
# 3                NaN         NaN  ...              1.0            NaN
# 4                NaN         NaN  ...              1.0            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                9.0          2016.0
# 1                         NaN            27516.0          2015.0
# 2                    660680.0          1434941.0          2016.0
# 3                    580059.0          1174475.0          2016.0
# 4                    196751.0           440101.0          2016.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0        NaN                 NaN                 NaN
# 1                27516.0        NaN                 NaN                 NaN
# 2               774261.0   20800.37                 NaN                 NaN
# 3               594416.0   14557.57                 NaN                 NaN
# 4               243350.0    5725.17                 NaN                 NaN
#
#    censustractandblock
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 58 columns]

# %%
train_2016 = pd.read_csv('../data/train_2016_v2.csv')
train_2016.head()
# Out:
#    parcelid  logerror transactiondate
# 0  11016594    0.0276      2016-01-01
# 1  14366692   -0.1684      2016-01-01
# 2  12098116   -0.0040      2016-01-01
# 3  12643413    0.0218      2016-01-02
# 4  14432541   -0.0050      2016-01-02

# %%
train_2017 = pd.read_csv('../data/train_2017.csv')
train_2016.head()
# Out:
#    parcelid  logerror transactiondate
# 0  11016594    0.0276      2016-01-01
# 1  14366692   -0.1684      2016-01-01
# 2  12098116   -0.0040      2016-01-01
# 3  12643413    0.0218      2016-01-02
# 4  14432541   -0.0050      2016-01-02

# %%
property_2016 = property_2016.merge(train_2016, on = 'parcelid', how = 'left')
property_2016.shape
# Out:
# (2985342, 60)

# %%
property_2017 = property_2017.merge(train_2017, on = 'parcelid', how = 'left')
property_2017.shape
# Out:
# (2985416, 60)

# %%
mask = property_2016['logerror'].notnull()
property_2016 = property_2016[mask]
property_2016.shape
# Out:
# (90275, 60)

# %%
mask = property_2017['logerror'].notnull()
property_2017 = property_2017[mask]
property_2017.shape
# Out:
# (77613, 60)

# %%
# only conduct EDA on 2016 to save runtime
df = pd.concat([property_2016, property_2017], axis = 0)
df.shape
# Out:
# (167888, 60)

# %%
df.head()
# Out:
#      parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 362  17073783                    NaN                       NaN           NaN
# 428  17088994                    NaN                       NaN           NaN
# 470  17100444                    NaN                       NaN           NaN
# 480  17102429                    NaN                       NaN           NaN
# 507  17109604                    NaN                       NaN           NaN
#
#      bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 362          2.5         3.0                  NaN                    NaN
# 428          1.0         2.0                  NaN                    NaN
# 470          2.0         3.0                  NaN                    NaN
# 480          1.5         2.0                  NaN                    NaN
# 507          2.5         4.0                  NaN                    NaN
#
#      calculatedbathnbr  decktypeid  ...  structuretaxvaluedollarcnt  \
# 362                2.5         NaN  ...                    115087.0
# 428                1.0         NaN  ...                    143809.0
# 470                2.0         NaN  ...                     33619.0
# 480                1.5         NaN  ...                     45609.0
# 507                2.5         NaN  ...                    277000.0
#
#      taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 362           191811.0          2015.0                76724.0    2015.06
# 428           239679.0          2015.0                95870.0    2581.30
# 470            47853.0          2015.0                14234.0     591.64
# 480            62914.0          2015.0                17305.0     682.78
# 507           554000.0          2015.0               277000.0    5886.92
#
#      taxdelinquencyflag  taxdelinquencyyear  censustractandblock  logerror  \
# 362                 NaN                 NaN         6.111002e+13    0.0953
# 428                 NaN                 NaN         6.111002e+13    0.0198
# 470                 NaN                 NaN         6.111001e+13    0.0060
# 480                 NaN                 NaN         6.111001e+13   -0.0566
# 507                 NaN                 NaN         6.111001e+13    0.0573
#
#      transactiondate
# 362       2016-01-27
# 428       2016-03-30
# 470       2016-05-27
# 480       2016-06-07
# 507       2016-08-08
#
# [5 rows x 60 columns]

# %%
df.columns
# Out:
# Index(['parcelid', 'airconditioningtypeid', 'architecturalstyletypeid',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingclasstypeid',
#        'buildingqualitytypeid', 'calculatedbathnbr', 'decktypeid',
#        'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'finishedsquarefeet13', 'finishedsquarefeet15',
#        'finishedsquarefeet50', 'finishedsquarefeet6', 'fips', 'fireplacecnt',
#        'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'hashottuborspa',
#        'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet',
#        'poolcnt', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7',
#        'propertycountylandusecode', 'propertylandusetypeid',
#        'propertyzoningdesc', 'rawcensustractandblock', 'regionidcity',
#        'regionidcounty', 'regionidneighborhood', 'regionidzip', 'roomcnt',
#        'storytypeid', 'threequarterbathnbr', 'typeconstructiontypeid',
#        'unitcnt', 'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt',
#        'numberofstories', 'fireplaceflag', 'structuretaxvaluedollarcnt',
#        'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt',
#        'taxamount', 'taxdelinquencyflag', 'taxdelinquencyyear',
#        'censustractandblock', 'logerror', 'transactiondate'],
#       dtype='object')

# %%
df.iloc[5,:]
# Out:
# parcelid                                17125829
# airconditioningtypeid                        NaN
# architecturalstyletypeid                     NaN
# basementsqft                                 NaN
# bathroomcnt                                  2.5
# bedroomcnt                                   4.0
# buildingclasstypeid                          NaN
# buildingqualitytypeid                        NaN
# calculatedbathnbr                            2.5
# decktypeid                                  66.0
# finishedfloor1squarefeet                  1303.0
# calculatedfinishedsquarefeet              2882.0
# finishedsquarefeet12                      2882.0
# finishedsquarefeet13                         NaN
# finishedsquarefeet15                         NaN
# finishedsquarefeet50                      1303.0
# finishedsquarefeet6                          NaN
# fips                                      6111.0
# fireplacecnt                                 1.0
# fullbathcnt                                  2.0
# garagecarcnt                                 2.0
# garagetotalsqft                            473.0
# hashottuborspa                               NaN
# heatingorsystemtypeid                        NaN
# latitude                              34240014.0
# longitude                           -119024793.0
# lotsizesquarefeet                        10000.0
# poolcnt                                      NaN
# poolsizesum                                  NaN
# pooltypeid10                                 NaN
# pooltypeid2                                  NaN
# pooltypeid7                                  NaN
# propertycountylandusecode                   1111
# propertylandusetypeid                      261.0
# propertyzoningdesc                           NaN
# rawcensustractandblock           61110052.022034
# regionidcity                             51239.0
# regionidcounty                            2061.0
# regionidneighborhood                         NaN
# regionidzip                              97089.0
# roomcnt                                      8.0
# storytypeid                                  NaN
# threequarterbathnbr                          1.0
# typeconstructiontypeid                       NaN
# unitcnt                                      NaN
# yardbuildingsqft17                           NaN
# yardbuildingsqft26                           NaN
# yearbuilt                                 1980.0
# numberofstories                              2.0
# fireplaceflag                                NaN
# structuretaxvaluedollarcnt              222070.0
# taxvaluedollarcnt                       289609.0
# assessmentyear                            2015.0
# landtaxvaluedollarcnt                    67539.0
# taxamount                                3110.44
# taxdelinquencyflag                           NaN
# taxdelinquencyyear                           NaN
# censustractandblock             61110052022034.0
# logerror                                  0.0564
# transactiondate                       2016-08-26
# Name: 555, dtype: object

# %%
df['fips'].value_counts()
# Out:
# 6037.0    109270
# 6059.0     45136
# 6111.0     13448
# Name: fips, dtype: int64

# %%
df['pooltypeid10'].value_counts()
# Out:
# 1.0    1626
# Name: pooltypeid10, dtype: int64

# %%
df['pooltypeid7'].value_counts()
# Out:
# 1.0    31776
# Name: pooltypeid7, dtype: int64

# %%
# remove
df['propertyzoningdesc'].value_counts()
# Out:
# LAR1          14444
# LAR3           5251
# LARS           2897
# LBR1N          2684
# LARD1.5        2437
#               ...
# NOR3              1
# DORI05*           1
# LCRA 30000        1
# SDDRA8000*        1
# G1R3*             1
# Name: propertyzoningdesc, Length: 2346, dtype: int64

# %%
# remove
df['rawcensustractandblock'].value_counts()
# Out:
# 6.037920e+07    142
# 6.059063e+07    133
# 6.037137e+07    109
# 6.059032e+07    105
# 6.037274e+07    104
#                ...
# 6.037120e+07      1
# 6.037621e+07      1
# 6.059052e+07      1
# 6.037311e+07      1
# 6.037651e+07      1
# Name: rawcensustractandblock, Length: 57789, dtype: int64

# %%
# remove
df['censustractandblock'].value_counts()
# Out:
# 6.037137e+13    109
# 6.059032e+13    103
# 6.037920e+13    103
# 6.037277e+13     96
# 6.059063e+13     87
#                ...
# 6.059074e+13      1
# 6.037101e+13      1
# 6.037463e+13      1
# 6.037297e+13      1
# 6.037296e+13      1
# Name: censustractandblock, Length: 57544, dtype: int64

# %%
# remove
df['regionidneighborhood'].value_counts()
# Out:
# 27080.0     1476
# 48570.0     1461
# 118208.0    1447
# 37739.0     1400
# 48200.0     1178
#             ...
# 764139.0       1
# 764136.0       1
# 761217.0       1
# 260382.0       1
# 272732.0       1
# Name: regionidneighborhood, Length: 505, dtype: int64

# %%
df.drop(['parcelid', 'propertycountylandusecode', 'propertyzoningdesc', 'rawcensustractandblock',
         'censustractandblock', 'regionidneighborhood'], axis = 1, inplace = True)

# %%
for col in df.columns:
    print(col)
    print(df[col].value_counts())
    print("==================================")
# Out:
# airconditioningtypeid
# 1.0     49854
# 13.0     3408
# 5.0       382
# 11.0      116
# 9.0        27
# 3.0         1
# Name: airconditioningtypeid, dtype: int64
# ==================================
# architecturalstyletypeid
# 7.0     394
# 8.0      35
# 2.0      16
# 21.0     15
# 3.0       7
# 10.0      1
# Name: architecturalstyletypeid, dtype: int64
# ==================================
# basementsqft
# 700.0     4
# 100.0     3
# 1528.0    3
# 515.0     3
# 1312.0    2
#          ..
# 38.0      1
# 608.0     1
# 485.0     1
# 512.0     1
# 260.0     1
# Name: basementsqft, Length: 78, dtype: int64
# ==================================
# bathroomcnt
# 2.0     68109
# 3.0     37300
# 1.0     27980
# 2.5     14698
# 4.0      7099
# 1.5      3060
# 5.0      2168
# 3.5      2127
# 0.0      1764
# 4.5      1491
# 6.0       867
# 5.5       477
# 7.0       269
# 8.0       222
# 6.5       101
# 9.0        59
# 7.5        25
# 10.0       21
# 11.0        6
# 8.5         4
# 12.0        3
# 20.0        1
# 18.0        1
# 15.0        1
# 13.0        1
# Name: bathroomcnt, dtype: int64
# ==================================
# bedroomcnt
# 3.0     65883
# 2.0     41580
# 4.0     37830
# 5.0      9627
# 1.0      7288
# 0.0      2258
# 6.0      2120
# 8.0       527
# 7.0       442
# 9.0       161
# 10.0       66
# 12.0       38
# 11.0       21
# 16.0        5
# 14.0        4
# 13.0        3
# 15.0        1
# Name: bedroomcnt, dtype: int64
# ==================================
# buildingclasstypeid
# 4.0    30
# 3.0     1
# Name: buildingclasstypeid, dtype: int64
# ==================================
# buildingqualitytypeid
# 7.0     35291
# 4.0     33347
# 8.0     14690
# 6.0     13503
# 1.0      2653
# 9.0      2303
# 5.0      2099
# 10.0     1774
# 11.0      934
# 3.0       335
# 12.0      235
# 2.0         9
# Name: buildingqualitytypeid, dtype: int64
# ==================================
# calculatedbathnbr
# 2.0     68109
# 3.0     37300
# 1.0     27980
# 2.5     14682
# 4.0      7099
# 1.5      3048
# 5.0      2168
# 3.5      2124
# 4.5      1489
# 6.0       867
# 5.5       476
# 7.0       269
# 8.0       222
# 6.5       101
# 9.0        59
# 7.5        25
# 10.0       21
# 11.0        6
# 8.5         4
# 12.0        3
# 15.0        1
# 20.0        1
# 18.0        1
# 13.0        1
# Name: calculatedbathnbr, dtype: int64
# ==================================
# decktypeid
# 66.0    1272
# Name: decktypeid, dtype: int64
# ==================================
# finishedfloor1squarefeet
# 1431.0    42
# 1226.0    41
# 1260.0    41
# 1252.0    39
# 1612.0    37
#           ..
# 3403.0     1
# 2306.0     1
# 6345.0     1
# 748.0      1
# 5273.0     1
# Name: finishedfloor1squarefeet, Length: 2274, dtype: int64
# ==================================
# calculatedfinishedsquarefeet
# 1200.0    370
# 1120.0    324
# 1080.0    312
# 1440.0    305
# 1040.0    269
#          ...
# 5102.0      1
# 4833.0      1
# 5750.0      1
# 6578.0      1
# 6282.0      1
# Name: calculatedfinishedsquarefeet, Length: 5825, dtype: int64
# ==================================
# finishedsquarefeet12
# 1200.0    361
# 1120.0    317
# 1080.0    308
# 1040.0    265
# 1300.0    258
#          ...
# 7200.0      1
# 6580.0      1
# 6667.0      1
# 9163.0      1
# 5390.0      1
# Name: finishedsquarefeet12, Length: 5729, dtype: int64
# ==================================
# finishedsquarefeet13
# 1440.0    35
# 1344.0     9
# 1248.0     5
# 1536.0     5
# 1392.0     4
# 1488.0     3
# 1152.0     3
# 1056.0     2
# 1200.0     1
# 1416.0     1
# 1560.0     1
# 1566.0     1
# 1584.0     1
# 1060.0     1
# 1512.0     1
# 1300.0     1
# 1464.0     1
# Name: finishedsquarefeet13, dtype: int64
# ==================================
# finishedsquarefeet15
# 1680.0    31
# 1536.0    24
# 1560.0    19
# 1600.0    19
# 1440.0    18
#           ..
# 896.0      1
# 2283.0     1
# 5229.0     1
# 3046.0     1
# 3350.0     1
# Name: finishedsquarefeet15, Length: 2619, dtype: int64
# ==================================
# finishedsquarefeet50
# 1431.0    42
# 1226.0    41
# 1260.0    40
# 1252.0    39
# 880.0     37
#           ..
# 572.0      1
# 3094.0     1
# 6805.0     1
# 1984.0     1
# 751.0      1
# Name: finishedsquarefeet50, Length: 2301, dtype: int64
# ==================================
# finishedsquarefeet6
# 3500.0    6
# 952.0     6
# 720.0     5
# 3470.0    5
# 2530.0    5
#          ..
# 942.0     1
# 962.0     1
# 2291.0    1
# 1574.0    1
# 1518.0    1
# Name: finishedsquarefeet6, Length: 649, dtype: int64
# ==================================
# fips
# 6037.0    109270
# 6059.0     45136
# 6111.0     13448
# Name: fips, dtype: int64
# ==================================
# fireplacecnt
# 1.0    15183
# 2.0     2104
# 3.0      547
# 4.0       56
# 5.0        6
# Name: fireplacecnt, dtype: int64
# ==================================
# fullbathcnt
# 2.0     82825
# 3.0     39429
# 1.0     31028
# 4.0      8594
# 5.0      2637
# 6.0       946
# 7.0       285
# 8.0       223
# 9.0        56
# 10.0       20
# 11.0        6
# 12.0        3
# 13.0        1
# 15.0        1
# 20.0        1
# 18.0        1
# Name: fullbathcnt, dtype: int64
# ==================================
# garagecarcnt
# 2.0     40580
# 1.0     12370
# 3.0      1295
# 0.0       520
# 4.0       518
# 5.0        99
# 6.0        30
# 7.0        15
# 8.0         9
# 9.0         8
# 10.0        5
# 11.0        3
# 14.0        2
# 13.0        2
# 24.0        1
# Name: garagecarcnt, dtype: int64
# ==================================
# garagetotalsqft
# 0.0       16909
# 400.0      1758
# 441.0      1474
# 462.0      1388
# 360.0      1383
#           ...
# 1230.0        1
# 1031.0        1
# 1154.0        1
# 313.0         1
# 211.0         1
# Name: garagetotalsqft, Length: 1035, dtype: int64
# ==================================
# hashottuborspa
# True    3904
# Name: hashottuborspa, dtype: int64
# ==================================
# heatingorsystemtypeid
# 2.0     71936
# 7.0     29626
# 24.0     1921
# 6.0      1747
# 20.0      201
# 13.0      136
# 18.0       48
# 1.0        26
# 10.0        5
# 14.0        2
# 11.0        2
# 12.0        1
# Name: heatingorsystemtypeid, dtype: int64
# ==================================
# latitude
# 33984600.0    107
# 33665651.0     79
# 33785200.0     61
# 34056700.0     61
# 33766300.0     59
#              ...
# 33685990.0      1
# 34036404.0      1
# 33882330.0      1
# 34269626.0      1
# 34286151.0      1
# Name: latitude, Length: 126379, dtype: int64
# ==================================
# longitude
# -118445000.0    142
# -118389000.0    134
# -118390000.0    130
# -118438000.0    120
# -118432000.0    116
#                ...
# -117805948.0      1
# -118130201.0      1
# -118332303.0      1
# -119228892.0      1
# -118105060.0      1
# Name: longitude, Length: 126312, dtype: int64
# ==================================
# lotsizesquarefeet
# 6000.0      2040
# 5000.0       913
# 7200.0       684
# 7000.0       652
# 6500.0       594
#             ...
# 23175.0        1
# 107593.0       1
# 48592.0        1
# 27053.0        1
# 1174.0         1
# Name: lotsizesquarefeet, Length: 25367, dtype: int64
# ==================================
# poolcnt
# 1.0    34075
# Name: poolcnt, dtype: int64
# ==================================
# poolsizesum
# 450.0    195
# 400.0     79
# 500.0     66
# 800.0     64
# 600.0     62
#         ...
# 990.0      1
# 855.0      1
# 885.0      1
# 836.0      1
# 463.0      1
# Name: poolsizesum, Length: 387, dtype: int64
# ==================================
# pooltypeid10
# 1.0    1626
# Name: pooltypeid10, dtype: int64
# ==================================
# pooltypeid2
# 1.0    2278
# Name: pooltypeid2, dtype: int64
# ==================================
# pooltypeid7
# 1.0    31776
# Name: pooltypeid7, dtype: int64
# ==================================
# propertylandusetypeid
# 261.0    113078
# 266.0     42157
# 246.0      4397
# 269.0      4281
# 248.0      1608
# 247.0      1168
# 265.0       691
# 263.0       158
# 275.0       105
# 260.0       104
# 267.0        57
# 31.0         32
# 264.0        17
# 47.0          1
# Name: propertylandusetypeid, dtype: int64
# ==================================
# regionidcity
# 12447.0    38562
# 46298.0     5596
# 54311.0     4010
# 5534.0      3951
# 52650.0     3802
#            ...
# 21395.0        4
# 24797.0        2
# 36078.0        1
# 37882.0        1
# 6285.0         1
# Name: regionidcity, Length: 178, dtype: int64
# ==================================
# regionidcounty
# 3101.0    109270
# 1286.0     45136
# 2061.0     13448
# Name: regionidcounty, dtype: int64
# ==================================
# regionidzip
# 97319.0    1737
# 96987.0    1655
# 97318.0    1438
# 96974.0    1419
# 97329.0    1348
#            ...
# 97111.0       2
# 96467.0       2
# 97092.0       1
# 97088.0       1
# 96034.0       1
# Name: regionidzip, Length: 390, dtype: int64
# ==================================
# roomcnt
# 0.0     129666
# 6.0       9876
# 7.0       8332
# 5.0       6509
# 8.0       6285
# 4.0       3096
# 9.0       2552
# 10.0       704
# 3.0        483
# 11.0       219
# 12.0        68
# 2.0         25
# 13.0        21
# 14.0        10
# 1.0          4
# 15.0         3
# 18.0         1
# Name: roomcnt, dtype: int64
# ==================================
# storytypeid
# 7.0    93
# Name: storytypeid, dtype: int64
# ==================================
# threequarterbathnbr
# 1.0    21934
# 2.0      165
# 3.0       14
# 7.0        1
# 4.0        1
# Name: threequarterbathnbr, dtype: int64
# ==================================
# typeconstructiontypeid
# 6.0     516
# 4.0       3
# 13.0      2
# 10.0      1
# Name: typeconstructiontypeid, dtype: int64
# ==================================
# unitcnt
# 1.0      101916
# 2.0        4385
# 4.0        1597
# 3.0        1148
# 6.0           2
# 42.0          1
# 237.0         1
# 11.0          1
# 9.0           1
# 45.0          1
# 5.0           1
# 143.0         1
# 70.0          1
# Name: unitcnt, dtype: int64
# ==================================
# yardbuildingsqft17
# 200.0     190
# 240.0     187
# 300.0     116
# 180.0      94
# 120.0      93
#          ...
# 733.0       1
# 606.0       1
# 17.0        1
# 1113.0      1
# 870.0       1
# Name: yardbuildingsqft17, Length: 749, dtype: int64
# ==================================
# yardbuildingsqft26
# 120.0     9
# 144.0     5
# 88.0      4
# 60.0      4
# 56.0      4
#          ..
# 1100.0    1
# 368.0     1
# 110.0     1
# 1248.0    1
# 268.0     1
# Name: yardbuildingsqft26, Length: 112, dtype: int64
# ==================================
# yearbuilt
# 1955.0    4236
# 1989.0    3846
# 1950.0    3670
# 1964.0    3567
# 1954.0    3530
#           ...
# 1866.0       1
# 1878.0       1
# 1882.0       1
# 1886.0       1
# 1889.0       1
# Name: yearbuilt, Length: 138, dtype: int64
# ==================================
# numberofstories
# 1.0    22413
# 2.0    14808
# 3.0      945
# 4.0        2
# 6.0        1
# Name: numberofstories, dtype: int64
# ==================================
# fireplaceflag
# True    394
# Name: fireplaceflag, dtype: int64
# ==================================
# structuretaxvaluedollarcnt
# 100000.0    168
# 200000.0    120
# 90000.0     113
# 150000.0    111
# 140000.0     98
#            ...
# 40958.0       1
# 116732.0      1
# 326093.0      1
# 184835.0      1
# 365784.0      1
# Name: structuretaxvaluedollarcnt, Length: 96512, dtype: int64
# ==================================
# taxvaluedollarcnt
# 400000.0     111
# 350000.0     108
# 420000.0     103
# 500000.0     102
# 450000.0      94
#             ...
# 334932.0       1
# 242580.0       1
# 353056.0       1
# 1006500.0      1
# 383110.0       1
# Name: taxvaluedollarcnt, Length: 102170, dtype: int64
# ==================================
# assessmentyear
# 2015.0    90275
# 2016.0    77579
# Name: assessmentyear, dtype: int64
# ==================================
# landtaxvaluedollarcnt
# 300000.0    116
# 20980.0     110
# 200000.0    101
# 21299.0      97
# 29757.0      83
#            ...
# 116393.0      1
# 102855.0      1
# 238964.0      1
# 293261.0      1
# 125121.0      1
# Name: landtaxvaluedollarcnt, Length: 102189, dtype: int64
# ==================================
# taxamount
# 2418.22     17
# 2388.63     14
# 1544.26     14
# 3720.52     13
# 1076.27     12
#             ..
# 5254.36      1
# 3795.86      1
# 6368.31      1
# 1947.87      1
# 21590.39     1
# Name: taxamount, Length: 149915, dtype: int64
# ==================================
# taxdelinquencyflag
# Y    4683
# Name: taxdelinquencyflag, dtype: int64
# ==================================
# taxdelinquencyyear
# 15.0    2078
# 14.0    1429
# 13.0     397
# 12.0     267
# 11.0     183
# 10.0     155
# 9.0      110
# 8.0       38
# 7.0       18
# 6.0        4
# 99.0       2
# 4.0        1
# 3.0        1
# Name: taxdelinquencyyear, dtype: int64
# ==================================
# logerror
#  0.003000    938
#  0.002000    915
#  0.005000    911
#  0.001000    901
#  0.007000    878
#             ...
# -0.002145      1
# -0.002169      1
# -0.143939      1
#  0.040114      1
# -0.073718      1
# Name: logerror, Length: 78958, dtype: int64
# ==================================
# transactiondate
# 2017-06-30    1195
# 2017-04-28     917
# 2016-07-29     910
# 2016-04-29     902
# 2016-09-30     894
#               ...
# 2017-09-10       1
# 2017-07-08       1
# 2017-03-12       1
# 2017-04-15       1
# 2017-08-05       1
# Name: transactiondate, Length: 616, dtype: int64
# ==================================

# %%
cat_col = ['airconditioningtypeid', 'architecturalstyletypeid', 'buildingclasstypeid', 'buildingqualitytypeid',
           'decktypeid', 'fips', 'hashottuborspa', 'heatingorsystemtypeid', 'poolcnt', 'poolsizesum', 
           'pooltypeid10', 'pooltypeid2', 'pooltypeid7', 'propertylandusetypeid', 'regionidcity', 'regionidcounty', 
           'regionidzip','storytypeid', 'typeconstructiontypeid', 'fireplaceflag', 'taxdelinquencyflag']

numeric_col = ['basementsqft', 'bathroomcnt', 'bedroomcnt', 'calculatedbathnbr', 'finishedfloor1squarefeet', 
               'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 'finishedsquarefeet13', 
               'finishedsquarefeet15', 'finishedsquarefeet50', 'finishedsquarefeet6', 'fireplacecnt', 
               'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'latitude', 'longitude', 'lotsizesquarefeet', 
               'roomcnt', 'threequarterbathnbr', 'unitcnt', 'yardbuildingsqft17', 'yardbuildingsqft26', 
               'yearbuilt', 'numberofstories', 'structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'assessmentyear', 
               'landtaxvaluedollarcnt', 'taxamount', 'taxdelinquencyyear', 'logerror']

date_col = ['transactiondate']

# %%
len(cat_col)
# Out:
# 21

# %%
len(numeric_col)
# Out:
# 32

# %%
df.shape
# Out:
# (167888, 54)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167888 entries, 362 to 2985381
# Data columns (total 54 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   airconditioningtypeid         53788 non-null   float64
#  1   architecturalstyletypeid      468 non-null     float64
#  2   basementsqft                  93 non-null      float64
#  3   bathroomcnt                   167854 non-null  float64
#  4   bedroomcnt                    167854 non-null  float64
#  5   buildingclasstypeid           31 non-null      float64
#  6   buildingqualitytypeid         107173 non-null  float64
#  7   calculatedbathnbr             166056 non-null  float64
#  8   decktypeid                    1272 non-null    float64
#  9   finishedfloor1squarefeet      12893 non-null   float64
#  10  calculatedfinishedsquarefeet  166992 non-null  float64
#  11  finishedsquarefeet12          159519 non-null  float64
#  12  finishedsquarefeet13          75 non-null      float64
#  13  finishedsquarefeet15          6591 non-null    float64
#  14  finishedsquarefeet50          12893 non-null   float64
#  15  finishedsquarefeet6           807 non-null     float64
#  16  fips                          167854 non-null  float64
#  17  fireplacecnt                  17896 non-null   float64
#  18  fullbathcnt                   166056 non-null  float64
#  19  garagecarcnt                  55457 non-null   float64
#  20  garagetotalsqft               55457 non-null   float64
#  21  hashottuborspa                3904 non-null    object
#  22  heatingorsystemtypeid         105651 non-null  float64
#  23  latitude                      167854 non-null  float64
#  24  longitude                     167854 non-null  float64
#  25  lotsizesquarefeet             149446 non-null  float64
#  26  poolcnt                       34075 non-null   float64
#  27  poolsizesum                   1838 non-null    float64
#  28  pooltypeid10                  1626 non-null    float64
#  29  pooltypeid2                   2278 non-null    float64
#  30  pooltypeid7                   31776 non-null   float64
#  31  propertylandusetypeid         167854 non-null  float64
#  32  regionidcity                  164579 non-null  float64
#  33  regionidcounty                167854 non-null  float64
#  34  regionidzip                   167769 non-null  float64
#  35  roomcnt                       167854 non-null  float64
#  36  storytypeid                   93 non-null      float64
#  37  threequarterbathnbr           22115 non-null   float64
#  38  typeconstructiontypeid        522 non-null     float64
#  39  unitcnt                       109056 non-null  float64
#  40  yardbuildingsqft17            5039 non-null    float64
#  41  yardbuildingsqft26            165 non-null     float64
#  42  yearbuilt                     166828 non-null  float64
#  43  numberofstories               38169 non-null   float64
#  44  fireplaceflag                 394 non-null     object
#  45  structuretaxvaluedollarcnt    167359 non-null  float64
#  46  taxvaluedollarcnt             167852 non-null  float64
#  47  assessmentyear                167854 non-null  float64
#  48  landtaxvaluedollarcnt         167851 non-null  float64
#  49  taxamount                     167843 non-null  float64
#  50  taxdelinquencyflag            4683 non-null    object
#  51  taxdelinquencyyear            4683 non-null    float64
#  52  logerror                      167888 non-null  float64
#  53  transactiondate               167888 non-null  object
# dtypes: float64(50), object(4)
# memory usage: 70.4+ MB

# %% [markdown]
# ## Numeric data

# %%
cat_property = df[cat_col]
numeric_property = df[numeric_col]

# %%
total = cat_property.isnull().sum().sort_values(ascending=False)
percent = (cat_property.isnull().sum()/cat_property.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(21)
# Out:
#                            Total   Percent
# buildingclasstypeid       167857  0.999815
# storytypeid               167795  0.999446
# fireplaceflag             167494  0.997653
# architecturalstyletypeid  167420  0.997212
# typeconstructiontypeid    167366  0.996891
# decktypeid                166616  0.992424
# pooltypeid10              166262  0.990315
# poolsizesum               166050  0.989052
# pooltypeid2               165610  0.986431
# hashottuborspa            163984  0.976746
# taxdelinquencyflag        163205  0.972106
# pooltypeid7               136112  0.810731
# poolcnt                   133813  0.797037
# airconditioningtypeid     114100  0.679620
# heatingorsystemtypeid      62237  0.370705
# buildingqualitytypeid      60715  0.361640
# regionidcity                3309  0.019710
# regionidzip                  119  0.000709
# propertylandusetypeid         34  0.000203
# regionidcounty                34  0.000203
# fips                          34  0.000203

# %%
total = numeric_property.isnull().sum().sort_values(ascending=False)
percent = (numeric_property.isnull().sum()/numeric_property.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(31)
# Out:
#                                Total   Percent
# finishedsquarefeet13          167813  0.999553
# basementsqft                  167795  0.999446
# yardbuildingsqft26            167723  0.999017
# finishedsquarefeet6           167081  0.995193
# taxdelinquencyyear            163205  0.972106
# yardbuildingsqft17            162849  0.969986
# finishedsquarefeet15          161297  0.960742
# finishedfloor1squarefeet      154995  0.923205
# finishedsquarefeet50          154995  0.923205
# fireplacecnt                  149992  0.893405
# threequarterbathnbr           145773  0.868275
# numberofstories               129719  0.772652
# garagetotalsqft               112431  0.669679
# garagecarcnt                  112431  0.669679
# unitcnt                        58832  0.350424
# lotsizesquarefeet              18442  0.109847
# finishedsquarefeet12            8369  0.049849
# fullbathcnt                     1832  0.010912
# calculatedbathnbr               1832  0.010912
# yearbuilt                       1060  0.006314
# calculatedfinishedsquarefeet     896  0.005337
# structuretaxvaluedollarcnt       529  0.003151
# taxamount                         45  0.000268
# landtaxvaluedollarcnt             37  0.000220
# taxvaluedollarcnt                 36  0.000214
# assessmentyear                    34  0.000203
# longitude                         34  0.000203
# roomcnt                           34  0.000203
# bathroomcnt                       34  0.000203
# latitude                          34  0.000203
# bedroomcnt                        34  0.000203

# %%
# remove the columns the percentage of null value of which is larger than 90%
df.drop(['basementsqft', 'yardbuildingsqft26', 'finishedsquarefeet13', 'finishedsquarefeet6',
                   'taxdelinquencyyear', 'yardbuildingsqft17', 'finishedsquarefeet15', 'finishedfloor1squarefeet',
                   'finishedsquarefeet50'], axis = 1, inplace = True)

# %%
numeric_col = []
for col in df.columns:
    if col not in cat_col:
        numeric_col.append(col)
print(numeric_col)
# Out:
# ['bathroomcnt', 'bedroomcnt', 'calculatedbathnbr', 'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 'fireplacecnt', 'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'latitude', 'longitude', 'lotsizesquarefeet', 'roomcnt', 'threequarterbathnbr', 'unitcnt', 'yearbuilt', 'numberofstories', 'structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt', 'taxamount', 'logerror', 'transactiondate']

# %%
len(numeric_col)
# Out:
# 24

# %%
numeric_property = df[numeric_col]
total = numeric_property.isnull().sum().sort_values(ascending=False)
percent = (numeric_property.isnull().sum()/numeric_property.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head()
# Out:
#                       Total   Percent
# fireplacecnt         149992  0.893405
# threequarterbathnbr  145773  0.868275
# numberofstories      129719  0.772652
# garagecarcnt         112431  0.669679
# garagetotalsqft      112431  0.669679

# %%
# replace null with mean value
df[numeric_col] = df[numeric_col].fillna(df[numeric_col].mean())

# %%
numeric_property = df[numeric_col]
total = numeric_property.isnull().sum().sort_values(ascending=False)
percent = (numeric_property.isnull().sum()/numeric_property.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head()
# Out:
#                        Total  Percent
# bathroomcnt                0      0.0
# bedroomcnt                 0      0.0
# logerror                   0      0.0
# taxamount                  0      0.0
# landtaxvaluedollarcnt      0      0.0

# %% [markdown]
# ## Category data

# %%
cat_property = df[cat_col]
total = cat_property.isnull().sum().sort_values(ascending=False)
percent = (cat_property.isnull().sum()/cat_property.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(len(cat_col))
# Out:
#                            Total   Percent
# buildingclasstypeid       167857  0.999815
# storytypeid               167795  0.999446
# fireplaceflag             167494  0.997653
# architecturalstyletypeid  167420  0.997212
# typeconstructiontypeid    167366  0.996891
# decktypeid                166616  0.992424
# pooltypeid10              166262  0.990315
# poolsizesum               166050  0.989052
# pooltypeid2               165610  0.986431
# hashottuborspa            163984  0.976746
# taxdelinquencyflag        163205  0.972106
# pooltypeid7               136112  0.810731
# poolcnt                   133813  0.797037
# airconditioningtypeid     114100  0.679620
# heatingorsystemtypeid      62237  0.370705
# buildingqualitytypeid      60715  0.361640
# regionidcity                3309  0.019710
# regionidzip                  119  0.000709
# propertylandusetypeid         34  0.000203
# regionidcounty                34  0.000203
# fips                          34  0.000203

# %% [markdown]
# BuildingClassTypeID
# 1	Buildings having fireproofed structural steel frames carrying all wall, floor and roof loads. Wall, floor and roof structures are built of non-combustible materials.
# 2	Buildings having fireproofed reinforced concrete frames carrying all wall floor and roof loads which are all non-combustible.
# 3	Buildings having exterior walls built of a non-combustible material such as brick, concrete, block or poured concrete. Interior partitions and roof structures are built of combustible materials. Floor may be concrete or wood frame.
# 4	Buildings having wood or wood and steel frames
# 5	Specialized buildings that do not fit in any of the above categories![image.png](attachment:image.png)

# %%
# not an important feature - remove
df.drop(['buildingclasstypeid'], axis = 1, inplace = True)

# %%
cat_col.remove('buildingclasstypeid')
cat_col
# Out:
# ['airconditioningtypeid',
#  'architecturalstyletypeid',
#  'buildingqualitytypeid',
#  'decktypeid',
#  'fips',
#  'hashottuborspa',
#  'heatingorsystemtypeid',
#  'poolcnt',
#  'poolsizesum',
#  'pooltypeid10',
#  'pooltypeid2',
#  'pooltypeid7',
#  'propertylandusetypeid',
#  'regionidcity',
#  'regionidcounty',
#  'regionidzip',
#  'storytypeid',
#  'typeconstructiontypeid',
#  'fireplaceflag',
#  'taxdelinquencyflag']

# %%
# 7: Basement
df['storytypeid'].value_counts()
df.drop(['storytypeid'], axis = 1, inplace = True)
cat_col.remove('storytypeid')

# %%
# replace binary column with False/0
# remove other category columns

tmp_col = ['architecturalstyletypeid', 'typeconstructiontypeid', 'decktypeid', 'pooltypeid10', 'poolsizesum', 
          'pooltypeid2', 'hashottuborspa', 'taxdelinquencyflag']
for i in tmp_col:
    print(df[i].value_counts())
# Out:
# 7.0     394
# 8.0      35
# 2.0      16
# 21.0     15
# 3.0       7
# 10.0      1
# Name: architecturalstyletypeid, dtype: int64
# 6.0     516
# 4.0       3
# 13.0      2
# 10.0      1
# Name: typeconstructiontypeid, dtype: int64
# 66.0    1272
# Name: decktypeid, dtype: int64
# 1.0    1626
# Name: pooltypeid10, dtype: int64
# 450.0    195
# 400.0     79
# 500.0     66
# 800.0     64
# 600.0     62
#         ...
# 990.0      1
# 855.0      1
# 885.0      1
# 836.0      1
# 463.0      1
# Name: poolsizesum, Length: 387, dtype: int64
# 1.0    2278
# Name: pooltypeid2, dtype: int64
# True    3904
# Name: hashottuborspa, dtype: int64
# Y    4683
# Name: taxdelinquencyflag, dtype: int64

# %%
df.drop(['architecturalstyletypeid', 'typeconstructiontypeid', 'decktypeid', 'poolsizesum'], axis = 1, inplace = True)
df.shape
# Out:
# (167888, 39)

# %%
cat_col = []
for item in df.columns:
    if item not in numeric_col:
        cat_col.append(item)

# %%
cat_col
# Out:
# ['airconditioningtypeid',
#  'buildingqualitytypeid',
#  'fips',
#  'hashottuborspa',
#  'heatingorsystemtypeid',
#  'poolcnt',
#  'pooltypeid10',
#  'pooltypeid2',
#  'pooltypeid7',
#  'propertylandusetypeid',
#  'regionidcity',
#  'regionidcounty',
#  'regionidzip',
#  'fireplaceflag',
#  'taxdelinquencyflag']

# %%
for i in range(0, len(cat_col)):
    column_name = cat_col[i]
    print(df[column_name].value_counts())
# Out:
# 1.0     49854
# 13.0     3408
# 5.0       382
# 11.0      116
# 9.0        27
# 3.0         1
# Name: airconditioningtypeid, dtype: int64
# 7.0     35291
# 4.0     33347
# 8.0     14690
# 6.0     13503
# 1.0      2653
# 9.0      2303
# 5.0      2099
# 10.0     1774
# 11.0      934
# 3.0       335
# 12.0      235
# 2.0         9
# Name: buildingqualitytypeid, dtype: int64
# 6037.0    109270
# 6059.0     45136
# 6111.0     13448
# Name: fips, dtype: int64
# True    3904
# Name: hashottuborspa, dtype: int64
# 2.0     71936
# 7.0     29626
# 24.0     1921
# 6.0      1747
# 20.0      201
# 13.0      136
# 18.0       48
# 1.0        26
# 10.0        5
# 14.0        2
# 11.0        2
# 12.0        1
# Name: heatingorsystemtypeid, dtype: int64
# 1.0    34075
# Name: poolcnt, dtype: int64
# 1.0    1626
# Name: pooltypeid10, dtype: int64
# 1.0    2278
# Name: pooltypeid2, dtype: int64
# 1.0    31776
# Name: pooltypeid7, dtype: int64
# 261.0    113078
# 266.0     42157
# 246.0      4397
# 269.0      4281
# 248.0      1608
# 247.0      1168
# 265.0       691
# 263.0       158
# 275.0       105
# 260.0       104
# 267.0        57
# 31.0         32
# 264.0        17
# 47.0          1
# Name: propertylandusetypeid, dtype: int64
# 12447.0    38562
# 46298.0     5596
# 54311.0     4010
# 5534.0      3951
# 52650.0     3802
#            ...
# 21395.0        4
# 24797.0        2
# 36078.0        1
# 37882.0        1
# 6285.0         1
# Name: regionidcity, Length: 178, dtype: int64
# 3101.0    109270
# 1286.0     45136
# 2061.0     13448
# Name: regionidcounty, dtype: int64
# 97319.0    1737
# 96987.0    1655
# 97318.0    1438
# 96974.0    1419
# 97329.0    1348
#            ...
# 97111.0       2
# 96467.0       2
# 97092.0       1
# 97088.0       1
# 96034.0       1
# Name: regionidzip, Length: 390, dtype: int64
# True    394
# Name: fireplaceflag, dtype: int64
# Y    4683
# Name: taxdelinquencyflag, dtype: int64

# %%
# 5 stands for None
df['airconditioningtypeid'].fillna(5, inplace = True)
df['airconditioningtypeid'].value_counts()
# Out:
# 5.0     114482
# 1.0      49854
# 13.0      3408
# 11.0       116
# 9.0         27
# 3.0          1
# Name: airconditioningtypeid, dtype: int64

# %%
# buildingqualitytypeid: Overall assessment of condition of the building from best (lowest) to worst (highest)
df['buildingqualitytypeid'].fillna(df['buildingqualitytypeid'].mode()[0], inplace = True)
df['buildingqualitytypeid'].value_counts()
# Out:
# 7.0     96006
# 4.0     33347
# 8.0     14690
# 6.0     13503
# 1.0      2653
# 9.0      2303
# 5.0      2099
# 10.0     1774
# 11.0      934
# 3.0       335
# 12.0      235
# 2.0         9
# Name: buildingqualitytypeid, dtype: int64

# %%
df['fips'].fillna(df['fips'].mode()[0], inplace = True)
df['fips'].value_counts()
# Out:
# 6037.0    109304
# 6059.0     45136
# 6111.0     13448
# Name: fips, dtype: int64

# %%
df['hashottuborspa'].fillna(False, inplace = True)
df['hashottuborspa'].value_counts()
# Out:
# False    163984
# True       3904
# Name: hashottuborspa, dtype: int64

# %%
# 13 stands for None
df['heatingorsystemtypeid'].fillna(13, inplace = True)
df['heatingorsystemtypeid'].value_counts()
# Out:
# 2.0     71936
# 13.0    62373
# 7.0     29626
# 24.0     1921
# 6.0      1747
# 20.0      201
# 18.0       48
# 1.0        26
# 10.0        5
# 14.0        2
# 11.0        2
# 12.0        1
# Name: heatingorsystemtypeid, dtype: int64

# %%
for item in ['poolcnt', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7', 'fireplaceflag', 'taxdelinquencyflag']:
    df[item].fillna(0, inplace = True)

# %%
sum(df['pooltypeid7'].isnull())
# Out:
# 0

# %%
# 261: SFR
df['propertylandusetypeid'].fillna(261, inplace = True)
df['propertylandusetypeid'].value_counts()
# Out:
# 261.0    113112
# 266.0     42157
# 246.0      4397
# 269.0      4281
# 248.0      1608
# 247.0      1168
# 265.0       691
# 263.0       158
# 275.0       105
# 260.0       104
# 267.0        57
# 31.0         32
# 264.0        17
# 47.0          1
# Name: propertylandusetypeid, dtype: int64

# %%
df['regionidcity'].fillna(df['regionidcity'].mode()[0], inplace = True)
df['regionidcounty'].fillna(df['regionidcounty'].mode()[0], inplace = True)
df['regionidzip'].fillna(df['regionidzip'].mode()[0], inplace = True)

# %%
cat_property = df[cat_col]
total = cat_property.isnull().sum().sort_values(ascending=False)
percent = (cat_property.isnull().sum()/cat_property.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head()
# Out:
#                        Total  Percent
# airconditioningtypeid      0      0.0
# buildingqualitytypeid      0      0.0
# fips                       0      0.0
# hashottuborspa             0      0.0
# heatingorsystemtypeid      0      0.0

# %%
df.head()
# Out:
#      airconditioningtypeid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 362                    5.0          2.5         3.0                    7.0
# 428                    5.0          1.0         2.0                    7.0
# 470                    5.0          2.0         3.0                    7.0
# 480                    5.0          1.5         2.0                    7.0
# 507                    5.0          2.5         4.0                    7.0
#
#      calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 362                2.5                        1264.0                1264.0
# 428                1.0                         777.0                 777.0
# 470                2.0                        1101.0                1101.0
# 480                1.5                        1554.0                1554.0
# 507                2.5                        2415.0                2415.0
#
#        fips  fireplacecnt  fullbathcnt  ...  numberofstories  fireplaceflag  \
# 362  6111.0      1.189428          2.0  ...              2.0              0
# 428  6111.0      1.189428          1.0  ...              1.0              0
# 470  6111.0      1.189428          2.0  ...              1.0              0
# 480  6111.0      1.000000          1.0  ...              1.0              0
# 507  6111.0      1.000000          2.0  ...              2.0              0
#
#      structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 362                    115087.0           191811.0          2015.0
# 428                    143809.0           239679.0          2015.0
# 470                     33619.0            47853.0          2015.0
# 480                     45609.0            62914.0          2015.0
# 507                    277000.0           554000.0          2015.0
#
#      landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  logerror  \
# 362                76724.0    2015.06                   0    0.0953
# 428                95870.0    2581.30                   0    0.0198
# 470                14234.0     591.64                   0    0.0060
# 480                17305.0     682.78                   0   -0.0566
# 507               277000.0    5886.92                   0    0.0573
#
#      transactiondate
# 362       2016-01-27
# 428       2016-03-30
# 470       2016-05-27
# 480       2016-06-07
# 507       2016-08-08
#
# [5 rows x 39 columns]

# %%
df.columns
# Out:
# Index(['airconditioningtypeid', 'bathroomcnt', 'bedroomcnt',
#        'buildingqualitytypeid', 'calculatedbathnbr',
#        'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 'fips',
#        'fireplacecnt', 'fullbathcnt', 'garagecarcnt', 'garagetotalsqft',
#        'hashottuborspa', 'heatingorsystemtypeid', 'latitude', 'longitude',
#        'lotsizesquarefeet', 'poolcnt', 'pooltypeid10', 'pooltypeid2',
#        'pooltypeid7', 'propertylandusetypeid', 'regionidcity',
#        'regionidcounty', 'regionidzip', 'roomcnt', 'threequarterbathnbr',
#        'unitcnt', 'yearbuilt', 'numberofstories', 'fireplaceflag',
#        'structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'assessmentyear',
#        'landtaxvaluedollarcnt', 'taxamount', 'taxdelinquencyflag', 'logerror',
#        'transactiondate'],
#       dtype='object')

# %%
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head()
# Out:
#                        Total  Percent
# airconditioningtypeid      0      0.0
# numberofstories            0      0.0
# regionidcity               0      0.0
# regionidcounty             0      0.0
# regionidzip                0      0.0

# %% [markdown]
# ## Data analysis

# %%
# y value distribution
ulimit = np.percentile(df.logerror.values, 99)
llimit = np.percentile(df.logerror.values, 1)
df['logerror'].iloc[df['logerror']>ulimit] = ulimit
df['logerror'].iloc[df['logerror']<llimit] = llimit

plt.figure(figsize=(12,8))
sns.distplot(df.logerror.values, bins=50, kde=False)
plt.xlabel('logerror', fontsize=12)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from datetime import datetime
df['transactiondate'] = [datetime.strptime(date, '%Y-%m-%d') for date in df['transactiondate']]

# %%
# transaction date analysis
color = sns.color_palette()
df['transaction_month'] = df['transactiondate'].dt.month

cnt_srs = df['transaction_month'].value_counts()
plt.figure(figsize=(12,6))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[3])
plt.xticks(rotation='vertical')
plt.xlabel('Month of transaction', fontsize=12)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# longtitude and latitude
# From the data page, we are provided with a full list of real estate properties in three counties 
# (Los Angeles, Orange and Ventura, California) data in 2016.
plt.figure(figsize=(12,12))
sns.jointplot(x=df.latitude.values, y=df.longitude.values, size=10)
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:2073: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#correlation matrix for numeric df
numeric_property = df[numeric_col]
corrmat = numeric_property.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=1.0, square=True)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#      airconditioningtypeid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 362                    5.0          2.5         3.0                    7.0
# 428                    5.0          1.0         2.0                    7.0
# 470                    5.0          2.0         3.0                    7.0
# 480                    5.0          1.5         2.0                    7.0
# 507                    5.0          2.5         4.0                    7.0
#
#      calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 362                2.5                        1264.0                1264.0
# 428                1.0                         777.0                 777.0
# 470                2.0                        1101.0                1101.0
# 480                1.5                        1554.0                1554.0
# 507                2.5                        2415.0                2415.0
#
#        fips  fireplacecnt  fullbathcnt  ...  fireplaceflag  \
# 362  6111.0      1.189428          2.0  ...              0
# 428  6111.0      1.189428          1.0  ...              0
# 470  6111.0      1.189428          2.0  ...              0
# 480  6111.0      1.000000          1.0  ...              0
# 507  6111.0      1.000000          2.0  ...              0
#
#      structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 362                    115087.0           191811.0          2015.0
# 428                    143809.0           239679.0          2015.0
# 470                     33619.0            47853.0          2015.0
# 480                     45609.0            62914.0          2015.0
# 507                    277000.0           554000.0          2015.0
#
#      landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  logerror  \
# 362                76724.0    2015.06                   0    0.0953
# 428                95870.0    2581.30                   0    0.0198
# 470                14234.0     591.64                   0    0.0060
# 480                17305.0     682.78                   0   -0.0566
# 507               277000.0    5886.92                   0    0.0573
#
#      transactiondate  transaction_month
# 362       2016-01-27                  1
# 428       2016-03-30                  3
# 470       2016-05-27                  5
# 480       2016-06-07                  6
# 507       2016-08-08                  8
#
# [5 rows x 40 columns]

# %%
#correlation matrix: feature vs logerror
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True, cmap = "Accent")
# Out:
# <AxesSubplot:>

# %% [markdown]
# According to the crystal ball, these are ten variables most correlated with 'logerror'.
# There are not any variables with strong correlation.
# The decision of an insurance product should consider every aspect of a client and no indicator plays a dominant role.

# %%
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'logerror')['logerror'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, 
                 yticklabels=cols.values, xticklabels=cols.values)
plt.show()
